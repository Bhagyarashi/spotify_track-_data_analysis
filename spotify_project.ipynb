# %%
import pandas as pd

# %%
data=pd.read_csv("spotify-2023.csv", encoding="ISO-8859-1")

# %%
data
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
data.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
data.tail()
# Out:
#                     track_name      artist(s)_name  artist_count  \
# 948               My Mind & Me        Selena Gomez             1
# 949  Bigger Than The Whole Sky        Taylor Swift             1
# 950       A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951              En La De Ella  Feid, Sech, Jhayco             3
# 952                      Alone           Burna Boy             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 948           2022              11             3                   953
# 949           2022              10            21                  1180
# 950           2022              11             3                   573
# 951           2022              10            20                  1320
# 952           2022              11             4                   782
#
#      in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
data.shape                                      #shows the number of rows and columns
# Out:
# (953, 24)

# %%
data.size                                   #shows the total number of values(elements) in the dataset
# Out:
# 22872

# %%
data.columns                               #shows name of each column in the dataset
# Out:
# Index(['track_name', 'artist(s)_name', 'artist_count', 'released_year',
#        'released_month', 'released_day', 'in_spotify_playlists',
#        'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts',
#        'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm',
#        'key', 'mode', 'danceability_%', 'valence_%', 'energy_%',
#        'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%'],
#       dtype='object')

# %%
data.dtypes                                #shows the datatype of each column
# Out:
# track_name              object
# artist(s)_name          object
# artist_count             int64
# released_year            int64
# released_month           int64
# released_day             int64
# in_spotify_playlists     int64
# in_spotify_charts        int64
# streams                 object
# in_apple_playlists       int64
# in_apple_charts          int64
# in_deezer_playlists     object
# in_deezer_charts         int64
# in_shazam_charts        object
# bpm                      int64
# key                     object
# mode                    object
# danceability_%           int64
# valence_%                int64
# energy_%                 int64
# acousticness_%           int64
# instrumentalness_%       int64
# liveness_%               int64
# speechiness_%            int64
# dtype: object

# %%
data.info()                                          #shows the info of complete dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    object
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      903 non-null    object
#  14  bpm                   953 non-null    int64
# ...

# %%
#check the duplicate records,if yes then remove it
data.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
data.shape
# Out:
# (953, 24)

# %%
data.duplicated()                                     #check row wise and detect the duplicate rows(boolean value)
# data[data.duplicated()]                   #shows the duplicate row, in this dataset there r no duplicate rows
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 948    False
# 949    False
# 950    False
# 951    False
# 952    False
# Length: 953, dtype: bool

# %%
data.drop_duplicates(inplace=True)                              #remove the duplicate rows permanently
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
#Is there any null value, if yes show with heat-map

data.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
data.isnull()                                           #to show where the null value is present
# Out:
#      track_name  artist(s)_name  artist_count  released_year  released_month  \
# 0         False           False         False          False           False
# 1         False           False         False          False           False
# 2         False           False         False          False           False
# 3         False           False         False          False           False
# 4         False           False         False          False           False
# ..          ...             ...           ...            ...             ...
# 948       False           False         False          False           False
# 949       False           False         False          False           False
# 950       False           False         False          False           False
# 951       False           False         False          False           False
# 952       False           False         False          False           False
#
# ...

# %%
data.isnull().sum()                                          #to show the total number of null values in each column
# Out:
# track_name               0
# artist(s)_name           0
# artist_count             0
# released_year            0
# released_month           0
# released_day             0
# in_spotify_playlists     0
# in_spotify_charts        0
# streams                  0
# in_apple_playlists       0
# in_apple_charts          0
# in_deezer_playlists      0
# in_deezer_charts         0
# in_shazam_charts        50
# bpm                      0
# key                     95
# mode                     0
# danceability_%           0
# valence_%                0
# energy_%                 0
# acousticness_%           0
# instrumentalness_%       0
# liveness_%               0
# speechiness_%            0
# dtype: int64

# %%
import seaborn as sns                      #to use the heat map import seaborn library

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
#for the track "cruel summer",who is the artist and the release year

# %%
data[data['track_name'].isin(['Cruel Summer'])]                         #to display a particular item of any column
# Out:
#      track_name artist(s)_name  artist_count  released_year  released_month  \
# 3  Cruel Summer   Taylor Swift             1           2019               8
#
#    released_day  in_spotify_playlists  in_spotify_charts    streams  \
# 3            23                  7858                100  800840817
#
#    in_apple_playlists  ...  bpm key   mode danceability_%  valence_% energy_%  \
# 3                 116  ...  170   A  Major             55         58       72
#
#   acousticness_%  instrumentalness_%  liveness_%  speechiness_%
# 3             11                   0          11             15
#
# [1 rows x 24 columns]

# %%
data['track_name'].str.contains('Cruel Summer')                         #it is similar to isin()
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 948    False
# 949    False
# 950    False
# 951    False
# 952    False
# Name: track_name, Length: 953, dtype: bool

# %%
#in which year highest number of songs were released?show with the bar graph

data.dtypes
# Out:
# track_name              object
# artist(s)_name          object
# artist_count             int64
# released_year            int64
# released_month           int64
# released_day             int64
# in_spotify_playlists     int64
# in_spotify_charts        int64
# streams                 object
# in_apple_playlists       int64
# in_apple_charts          int64
# in_deezer_playlists     object
# in_deezer_charts         int64
# in_shazam_charts        object
# bpm                      int64
# key                     object
# mode                    object
# danceability_%           int64
# valence_%                int64
# energy_%                 int64
# acousticness_%           int64
# instrumentalness_%       int64
# liveness_%               int64
# speechiness_%            int64
# dtype: object

# %%
data['Date_N']=pd.to_datetime()           #creating new column Date_N
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 data['Date_N']=pd.to_datetime()
#
# TypeError: to_datetime() missing 1 required positional argument: 'arg'

# %%
data.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  key   mode  \
# ...

# %%
data.dtypes
# Out:
# track_name                      object
# artist(s)_name                  object
# artist_count                     int64
# released_year                    int64
# released_month                   int64
# released_day                     int64
# in_spotify_playlists             int64
# in_spotify_charts                int64
# streams                         object
# in_apple_playlists               int64
# in_apple_charts                  int64
# in_deezer_playlists             object
# in_deezer_charts                 int64
# in_shazam_charts                object
# bpm                              int64
# key                             object
# mode                            object
# danceability_%                   int64
# valence_%                        int64
# energy_%                         int64
# acousticness_%                   int64
# instrumentalness_%               int64
# liveness_%                       int64
# speechiness_%                    int64
# ...

# %%
data['Date_N'].dt.year.value_counts()
# Out:
# 1970    953
# Name: Date_N, dtype: int64

# %%
data['Date_N'].dt.year.value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
data
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
# how many songs are major and minor?show with bar graph

data.groupby('released_year').released_year.count()
# Out:
# released_year
# 1930      1
# 1942      1
# 1946      1
# 1950      1
# 1952      1
# 1957      2
# 1958      3
# 1959      2
# 1963      3
# 1968      1
# 1970      2
# 1971      1
# 1973      1
# 1975      2
# 1979      1
# 1982      2
# 1983      1
# 1984      4
# 1985      2
# 1986      2
# 1987      1
# 1991      2
# 1992      1
# 1994      1
# 1995      2
# 1996      1
# 1997      1
# 1998      1
# 1999      5
# 2000      4
# 2002      6
# 2003      2
# 2004      4
# 2005      1
# 2007      1
# 2008      2
# 2010      7
# 2011     10
# 2012     10
# 2013     13
# 2014     13
# 2015     11
# 2016     18
# 2017     23
# 2018     10
# 2019     36
# 2020     37
# 2021    119
# 2022    402
# 2023    175
# Name: released_year, dtype: int64

# %%
sns.countplot(data['released_year'])
# Out:
# <Axes: ylabel='count'>

# %%
#FILTERING(songs sung by taylor swift and released in 2014)

data[(data['artist(s)_name']=='Taylor Swift') & (data['released_year']==2014)]
# Out:
#        track_name artist(s)_name  artist_count  released_year  released_month  \
# 37    Blank Space   Taylor Swift             1           2014               1
# 38          Style   Taylor Swift             1           2014               1
# 176  Shake It Off   Taylor Swift             1           2014               1
#
#      released_day  in_spotify_playlists  in_spotify_charts     streams  \
# 37              1                 11434                 53  1355959075
# 38              1                  7830                 42   786181836
# 176             1                 21335                 13  1113838873
#
#      in_apple_playlists  ...  bpm key   mode danceability_%  valence_%  \
# 37                  154  ...   96   F  Major             75         57
# 38                   94  ...   95   D  Major             60         48
# 176                 328  ...  160   G  Major             65         95
#
#     energy_% acousticness_%  instrumentalness_%  liveness_%  speechiness_%
# ...

# %%
# similar to the prevoius cell but shows only the track_name column
data[(data['artist(s)_name']=='Taylor Swift') & (data['released_year']==2014)] ['track_name']
# Out:
# 37      Blank Space
# 38            Style
# 176    Shake It Off
# Name: track_name, dtype: object

# %%
data
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
data.groupby('streams').streams.count()
# Out:
# streams
# 100409613                                                                                                 1
# 1007612429                                                                                                1
# 101114984                                                                                                 1
# 101780047                                                                                                 1
# 1022258230                                                                                                1
#                                                                                                          ..
# 98709329                                                                                                  1
# 988515741                                                                                                 1
# 991336132                                                                                                 1
# ...

# %%
data.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
# FILTERING using AND ,OR operators
data[(data['artist(s)_name']=='Taylor Swift') & (data['released_year']==2022) | (data['mode']=='Major')]
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 5                               Sprinter   Dave, Central Cee             2
# ..                                   ...                 ...           ...
# 947                        The Great War        Taylor Swift             1
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
#
# ...

# %%
# how many songs are sung by Selena Gomez
data[data['artist(s)_name']=='Selena Gomez'].shape                      #only 1 song is sung by selena
# Out:
# (1, 24)

# %%
data[data['artist(s)_name'].str.contains('Weekend')]               #same as previous cell using str.contains()
# Out:
# Empty DataFrame
# Columns: [track_name, artist(s)_name, artist_count, released_year, released_month, released_day, in_spotify_playlists, in_spotify_charts, streams, in_apple_playlists, in_apple_charts, in_deezer_playlists, in_deezer_charts, in_shazam_charts, bpm, key, mode, danceability_%, valence_%, energy_%, acousticness_%, instrumentalness_%, liveness_%, speechiness_%]
# Index: []
#
# [0 rows x 24 columns]

# %%
# Removing null values
data_new=data.dropna()                            # drops all the missing or null values

# %%
data_new.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
print(data.isna())
# Out:
#      track_name  artist(s)_name  artist_count  released_year  released_month  \
# 0         False           False         False          False           False
# 1         False           False         False          False           False
# 2         False           False         False          False           False
# 3         False           False         False          False           False
# 4         False           False         False          False           False
# ..          ...             ...           ...            ...             ...
# 948       False           False         False          False           False
# 949       False           False         False          False           False
# 950       False           False         False          False           False
# 951       False           False         False          False           False
# 952       False           False         False          False           False
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    object
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      903 non-null    object
#  14  bpm                   953 non-null    int64
# ...

# %%
data.isna().sum()
# Out:
# track_name               0
# artist(s)_name           0
# artist_count             0
# released_year            0
# released_month           0
# released_day             0
# in_spotify_playlists     0
# in_spotify_charts        0
# streams                  0
# in_apple_playlists       0
# in_apple_charts          0
# in_deezer_playlists      0
# in_deezer_charts         0
# in_shazam_charts        50
# bpm                      0
# key                     95
# mode                     0
# danceability_%           0
# valence_%                0
# energy_%                 0
# acousticness_%           0
# instrumentalness_%       0
# liveness_%               0
# speechiness_%            0
# dtype: int64

# %%
data_new
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
data
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
data['key'].nunique()
# Out:
# 11

# %%
data['key'].unique()
# Out:
# array(['B', 'C#', 'F', 'A', 'D', 'F#', nan, 'G#', 'G', 'E', 'A#', 'D#'],
#       dtype=object)

# %%
data.key.dtypes
# Out:
# dtype('O')

# %%
# using max() function
data['in_spotify_playlists'].max()
# Out:
# 52898

# %%
# using min() function
data['in_spotify_playlists'].min()
# Out:
# 31

# %%
# sorting the dataset by year
data.sort_values(by='released_year').head(10)
# Out:
#                                             track_name  \
# 439                                    Agudo Mï¿½ï¿½gi
# 469                                    White Christmas
# 460  The Christmas Song (Merry Christmas To You) - ...
# 466             Let It Snow! Let It Snow! Let It Snow!
# 459           A Holly Jolly Christmas - Single Version
# 444                                   Jingle Bell Rock
# 496                     Jingle Bells - Remastered 1999
# 443                  Rockin' Around The Christmas Tree
# 476  It's Beginning to Look a Lot Like Christmas (w...
# 495                   Run Rudolph Run - Single Version
#
#                                         artist(s)_name  artist_count  \
# 439                            Styrx, utku INC, Thezth             3
# 469  Bing Crosby, John Scott Trotter & His Orchestr...             3
# 460                                      Nat King Cole             1
# 466                  Frank Sinatra, B. Swanson Quartet             2
# ...

# %%
data.sort_values(by='released_year',ascending=False).head(20)         # reverse sorting(latest released year)
# Out:
#                                             track_name  \
# 0                  Seven (feat. Latto) (Explicit Ver.)
# 210                                           Abcdario
# 351                                           PERO Tï¿
# 174                                       ýýýýýýýýýýýý
# 348                                 Red Ruby Da Sleeze
# 347                 Man Made A Bar (feat. Eric Church)
# 181                                      Fin de Semana
# 343                                   I Wrote The Book
# 342                                               Sial
# 185                                            Cheques
# 340                                             Heaven
# 339                                  Everything I Love
# 338     Private Landing (feat. Justin Bieber & Future)
# 337                                 Thinkinï¿½ï¿½ï¿½ B
# 336                                  Ainï¿½ï¿½ï¿½t Tha
# 193             Better Than Revenge (Taylor's Version)
# ...

# %%
data[(data['artist(s)_name']=='j-hope') & (data['released_year']==2022) | (data['artist(s)_name']=='Morgan Wallen') & (data['released_year']==2022)]
# Out:
#                   track_name artist(s)_name  artist_count  released_year  \
# 316                You Proof  Morgan Wallen             1           2022
# 334      One Thing At A Time  Morgan Wallen             1           2022
# 357  Thought You Should Know  Morgan Wallen             1           2022
# 870                     MORE         j-hope             1           2022
#
#      released_month  released_day  in_spotify_playlists  in_spotify_charts  \
# 316               5            13                  2128                  9
# 334              12             2                   811                  4
# 357               5             6                   968                  4
# 870               7             1                   565                  0
#
#        streams  in_apple_playlists  ...  bpm key   mode danceability_%  \
# 316  367814306                  37  ...  120   A  Major             73
# 334  148469433                  11  ...  142   G  Major             61
# ...
